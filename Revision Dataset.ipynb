# %% [markdown]
# ### Importar Librerias
#
# pandas
# numpy
# seaborn
# matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Lectura de archivo CSV

# %%
df= pd.read_csv("Dataset/CreditRisk.csv")

# Para seleccionar los encabezados 
df.head(33)
# Out:
#      status  seniority     home  time  age  marital records        job  \
# 0        ok          9     rent    60   30  married      no  freelance
# 1        ok         17     rent    60   58    widow      no      fixed
# 2   default         10    owner    36   46  married     yes  freelance
# 3        ok          0     rent    60   24   single      no      fixed
# 4        ok          0     rent    36   26   single      no      fixed
# 5        ok          1    owner    60   36  married      no      fixed
# 6        ok         29    owner    60   44  married      no      fixed
# 7        ok          9  parents    12   27   single      no      fixed
# 8        ok          0    owner    60   32  married      no  freelance
# 9   default          0  parents    48   41  married      no    partime
# 10       ok          6    owner    48   34  married      no  freelance
# 11       ok          7    owner    36   29  married      no      fixed
# 12       ok          8    owner    60   30  married      no      fixed
# 13       ok         19  private    36   37  married      no      fixed
# 14  default          0    other    18   21   single     yes    partime
# 15       ok          0    owner    24   68  married      no      fixed
# 16       ok         15  private    24   52   single      no  freelance
# 17       ok         33     rent    24   68  married      no  freelance
# 18  default          0   ignore    48   36  married      no    partime
# 19       ok          1  parents    60   31   single      no      fixed
# 20  default          2     rent    60   25   single      no      fixed
# 21       ok          5    owner    60   22   single      no      fixed
# 22  default          1    owner    60   45  married      no    partime
# 23       ok         27     rent    60   41  married      no      fixed
# 24       ok         26    owner    60   51  married      no      fixed
# 25       ok         12    owner    36   54  married      no      fixed
# 26       ok         19    owner    60   43   single      no      fixed
# 27       ok         15    owner    36   43  married      no      fixed
# 28  default          3    owner    24   23  married      no      fixed
# 29  default          0      unk    48   37   single      no        unk
# 30       ok          4    owner    48   29  married      no      fixed
# 31  default          0    owner    36   23   single      no    partime
# 32       ok         14  private    24   51  married      no    partime
#
#     expenses    income    assets      debt  amount  price
# 0         73       129         0         0     800    846
# 1         48       131         0         0    1000   1658
# 2         90       200      3000         0    2000   2985
# 3         63       182      2500         0     900   1325
# 4         46       107         0         0     310    910
# 5         75       214      3500         0     650   1645
# 6         75       125     10000         0    1600   1800
# 7         35        80         0         0     200   1093
# 8         90       107     15000         0    1200   1957
# 9         90        80         0         0    1200   1468
# 10        60       125      4000         0    1150   1577
# 11        60       121      3000         0     650    915
# 12        75       199      5000      2500    1500   1650
# 13        75       170      3500       260     600    940
# 14        35        50         0         0     400    500
# 15        75       131      4162         0     900   1186
# 16        35       330     16500         0    1500   2201
# 17        65       200      5000      2000     600   1350
# 18        45       130       750         0    1100   1511
# 19        35       137         0         0    1250   1253
# 20        46       107         0         0    1500   2189
# 21        45       324     10000         0    1100   1159
# 22       105       112      2000       500     600   1332
# 23        74       140         0         0     950   1497
# 24        45       143      3500         0    1350   1357
# 25        60       130      4000         0     700   2100
# 26        75       180      4000         0    1000   1070
# 27        75       251      4000         0    1800   2557
# 28        75        85      5000         0     600   1600
# 29        35  99999999  99999999  99999999    1500   1850
# 30        45       150      5000      3300    1100   1312
# 31        45       122      2500         0     400    400
# 32        75       198      1000         0     450    650

# %% [markdown]
# ### Mostrar info Basica de un DF

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4455 entries, 0 to 4454
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   status     4455 non-null   object
#  1   seniority  4455 non-null   int64
#  2   home       4455 non-null   object
#  3   time       4455 non-null   int64
#  4   age        4455 non-null   int64
#  5   marital    4455 non-null   object
#  6   records    4455 non-null   object
#  7   job        4455 non-null   object
#  8   expenses   4455 non-null   int64
#  9   income     4455 non-null   int64
#  10  assets     4455 non-null   int64
#  11  debt       4455 non-null   int64
#  12  amount     4455 non-null   int64
#  13  price      4455 non-null   int64
# dtypes: int64(9), object(5)
# memory usage: 487.4+ KB

# %% [markdown]
# ### Visualizar los tipos de datos de nuestra base

# %%
df.dtypes
# Out:
# status       object
# seniority     int64
# home         object
# time          int64
# age           int64
# marital      object
# records      object
# job          object
# expenses      int64
# income        int64
# assets        int64
# debt          int64
# amount        int64
# price         int64
# dtype: object

# %% [markdown]
# ### Validar Nulos

# %%
df.isnull()
# Out:
#       status  seniority   home   time    age  marital  records    job  \
# 0      False      False  False  False  False    False    False  False
# 1      False      False  False  False  False    False    False  False
# 2      False      False  False  False  False    False    False  False
# 3      False      False  False  False  False    False    False  False
# 4      False      False  False  False  False    False    False  False
# ...      ...        ...    ...    ...    ...      ...      ...    ...
# 4450   False      False  False  False  False    False    False  False
# 4451   False      False  False  False  False    False    False  False
# 4452   False      False  False  False  False    False    False  False
# 4453   False      False  False  False  False    False    False  False
# 4454   False      False  False  False  False    False    False  False
#
#       expenses  income  assets   debt  amount  price
# 0        False   False   False  False   False  False
# 1        False   False   False  False   False  False
# 2        False   False   False  False   False  False
# 3        False   False   False  False   False  False
# 4        False   False   False  False   False  False
# ...        ...     ...     ...    ...     ...    ...
# 4450     False   False   False  False   False  False
# 4451     False   False   False  False   False  False
# 4452     False   False   False  False   False  False
# 4453     False   False   False  False   False  False
# 4454     False   False   False  False   False  False
#
# [4455 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# status       0
# seniority    0
# home         0
# time         0
# age          0
# marital      0
# records      0
# job          0
# expenses     0
# income       0
# assets       0
# debt         0
# amount       0
# price        0
# dtype: int64

# %% [markdown]
# ### Describir de forma Estaistica y redondeado

# %%
df.describe().round()
# Out:
#        seniority    time     age  expenses      income      assets  \
# count     4455.0  4455.0  4455.0    4455.0      4455.0      4455.0
# mean         8.0    46.0    37.0      56.0    763317.0   1060341.0
# std          8.0    15.0    11.0      20.0   8703625.0  10217569.0
# min          0.0     6.0    18.0      35.0         0.0         0.0
# 25%          2.0    36.0    28.0      35.0        80.0         0.0
# 50%          5.0    48.0    36.0      51.0       120.0      3500.0
# 75%         12.0    60.0    45.0      72.0       166.0      6000.0
# max         48.0    72.0    68.0     180.0  99999999.0  99999999.0
#
#              debt  amount    price
# count      4455.0  4455.0   4455.0
# mean     404382.0  1039.0   1463.0
# std     6344253.0   475.0    628.0
# min           0.0   100.0    105.0
# 25%           0.0   700.0   1118.0
# 50%           0.0  1000.0   1400.0
# 75%           0.0  1300.0   1692.0
# max    99999999.0  5000.0  11140.0

# %% [markdown]
# ### Limpieza de base de datos

# %%
for c in ["income", "assets", "debt"]:
    df[c]= df[c].replace(to_replace=99999999, value=np.nan)

# %%
df.head(35)
# Out:
#      status  seniority     home  time  age  marital records        job  \
# 0        ok          9     rent    60   30  married      no  freelance
# 1        ok         17     rent    60   58    widow      no      fixed
# 2   default         10    owner    36   46  married     yes  freelance
# 3        ok          0     rent    60   24   single      no      fixed
# 4        ok          0     rent    36   26   single      no      fixed
# 5        ok          1    owner    60   36  married      no      fixed
# 6        ok         29    owner    60   44  married      no      fixed
# 7        ok          9  parents    12   27   single      no      fixed
# 8        ok          0    owner    60   32  married      no  freelance
# 9   default          0  parents    48   41  married      no    partime
# 10       ok          6    owner    48   34  married      no  freelance
# 11       ok          7    owner    36   29  married      no      fixed
# 12       ok          8    owner    60   30  married      no      fixed
# 13       ok         19  private    36   37  married      no      fixed
# 14  default          0    other    18   21   single     yes    partime
# 15       ok          0    owner    24   68  married      no      fixed
# 16       ok         15  private    24   52   single      no  freelance
# 17       ok         33     rent    24   68  married      no  freelance
# 18  default          0   ignore    48   36  married      no    partime
# 19       ok          1  parents    60   31   single      no      fixed
# 20  default          2     rent    60   25   single      no      fixed
# 21       ok          5    owner    60   22   single      no      fixed
# 22  default          1    owner    60   45  married      no    partime
# 23       ok         27     rent    60   41  married      no      fixed
# 24       ok         26    owner    60   51  married      no      fixed
# 25       ok         12    owner    36   54  married      no      fixed
# 26       ok         19    owner    60   43   single      no      fixed
# 27       ok         15    owner    36   43  married      no      fixed
# 28  default          3    owner    24   23  married      no      fixed
# 29  default          0      unk    48   37   single      no        unk
# 30       ok          4    owner    48   29  married      no      fixed
# 31  default          0    owner    36   23   single      no    partime
# 32       ok         14  private    24   51  married      no    partime
# 33       ok         10    owner    36   39  married      no  freelance
# 34       ok         12  parents    36   35   single      no      fixed
#
#     expenses  income   assets    debt  amount  price
# 0         73   129.0      0.0     0.0     800    846
# 1         48   131.0      0.0     0.0    1000   1658
# 2         90   200.0   3000.0     0.0    2000   2985
# 3         63   182.0   2500.0     0.0     900   1325
# 4         46   107.0      0.0     0.0     310    910
# 5         75   214.0   3500.0     0.0     650   1645
# 6         75   125.0  10000.0     0.0    1600   1800
# 7         35    80.0      0.0     0.0     200   1093
# 8         90   107.0  15000.0     0.0    1200   1957
# 9         90    80.0      0.0     0.0    1200   1468
# 10        60   125.0   4000.0     0.0    1150   1577
# 11        60   121.0   3000.0     0.0     650    915
# 12        75   199.0   5000.0  2500.0    1500   1650
# 13        75   170.0   3500.0   260.0     600    940
# 14        35    50.0      0.0     0.0     400    500
# 15        75   131.0   4162.0     0.0     900   1186
# 16        35   330.0  16500.0     0.0    1500   2201
# 17        65   200.0   5000.0  2000.0     600   1350
# 18        45   130.0    750.0     0.0    1100   1511
# 19        35   137.0      0.0     0.0    1250   1253
# 20        46   107.0      0.0     0.0    1500   2189
# 21        45   324.0  10000.0     0.0    1100   1159
# 22       105   112.0   2000.0   500.0     600   1332
# 23        74   140.0      0.0     0.0     950   1497
# 24        45   143.0   3500.0     0.0    1350   1357
# 25        60   130.0   4000.0     0.0     700   2100
# 26        75   180.0   4000.0     0.0    1000   1070
# 27        75   251.0   4000.0     0.0    1800   2557
# 28        75    85.0   5000.0     0.0     600   1600
# 29        35     NaN      NaN     NaN    1500   1850
# 30        45   150.0   5000.0  3300.0    1100   1312
# 31        45   122.0   2500.0     0.0     400    400
# 32        75   198.0   1000.0     0.0     450    650
# 33        75   150.0   3000.0     0.0    1000   1394
# 34        35   170.0      0.0     0.0    1100   1542

# %% [markdown]
# ### -variable dependiente (Limpieza de base de datos)

# %%
df.status.value_counts()
# Out:
# status
# ok         3200
# default    1254
# unk           1
# Name: count, dtype: int64

# %%
df= df[df.status != "unk"]

# %%
df.isnull().sum()
# Out:
# status        0
# seniority     0
# home          0
# time          0
# age           0
# marital       0
# records       0
# job           0
# expenses      0
# income       34
# assets       47
# debt         18
# amount        0
# price         0
# dtype: int64

# %%
df.head(33)
# Out:
#      status  seniority     home  time  age  marital records        job  \
# 0        ok          9     rent    60   30  married      no  freelance
# 1        ok         17     rent    60   58    widow      no      fixed
# 2   default         10    owner    36   46  married     yes  freelance
# 3        ok          0     rent    60   24   single      no      fixed
# 4        ok          0     rent    36   26   single      no      fixed
# 5        ok          1    owner    60   36  married      no      fixed
# 6        ok         29    owner    60   44  married      no      fixed
# 7        ok          9  parents    12   27   single      no      fixed
# 8        ok          0    owner    60   32  married      no  freelance
# 9   default          0  parents    48   41  married      no    partime
# 10       ok          6    owner    48   34  married      no  freelance
# 11       ok          7    owner    36   29  married      no      fixed
# 12       ok          8    owner    60   30  married      no      fixed
# 13       ok         19  private    36   37  married      no      fixed
# 14  default          0    other    18   21   single     yes    partime
# 15       ok          0    owner    24   68  married      no      fixed
# 16       ok         15  private    24   52   single      no  freelance
# 17       ok         33     rent    24   68  married      no  freelance
# 18  default          0   ignore    48   36  married      no    partime
# 19       ok          1  parents    60   31   single      no      fixed
# 20  default          2     rent    60   25   single      no      fixed
# 21       ok          5    owner    60   22   single      no      fixed
# 22  default          1    owner    60   45  married      no    partime
# 23       ok         27     rent    60   41  married      no      fixed
# 24       ok         26    owner    60   51  married      no      fixed
# 25       ok         12    owner    36   54  married      no      fixed
# 26       ok         19    owner    60   43   single      no      fixed
# 27       ok         15    owner    36   43  married      no      fixed
# 28  default          3    owner    24   23  married      no      fixed
# 29  default          0      unk    48   37   single      no        unk
# 30       ok          4    owner    48   29  married      no      fixed
# 31  default          0    owner    36   23   single      no    partime
# 32       ok         14  private    24   51  married      no    partime
#
#     expenses  income   assets    debt  amount  price
# 0         73   129.0      0.0     0.0     800    846
# 1         48   131.0      0.0     0.0    1000   1658
# 2         90   200.0   3000.0     0.0    2000   2985
# 3         63   182.0   2500.0     0.0     900   1325
# 4         46   107.0      0.0     0.0     310    910
# 5         75   214.0   3500.0     0.0     650   1645
# 6         75   125.0  10000.0     0.0    1600   1800
# 7         35    80.0      0.0     0.0     200   1093
# 8         90   107.0  15000.0     0.0    1200   1957
# 9         90    80.0      0.0     0.0    1200   1468
# 10        60   125.0   4000.0     0.0    1150   1577
# 11        60   121.0   3000.0     0.0     650    915
# 12        75   199.0   5000.0  2500.0    1500   1650
# 13        75   170.0   3500.0   260.0     600    940
# 14        35    50.0      0.0     0.0     400    500
# 15        75   131.0   4162.0     0.0     900   1186
# 16        35   330.0  16500.0     0.0    1500   2201
# 17        65   200.0   5000.0  2000.0     600   1350
# 18        45   130.0    750.0     0.0    1100   1511
# 19        35   137.0      0.0     0.0    1250   1253
# 20        46   107.0      0.0     0.0    1500   2189
# 21        45   324.0  10000.0     0.0    1100   1159
# 22       105   112.0   2000.0   500.0     600   1332
# 23        74   140.0      0.0     0.0     950   1497
# 24        45   143.0   3500.0     0.0    1350   1357
# 25        60   130.0   4000.0     0.0     700   2100
# 26        75   180.0   4000.0     0.0    1000   1070
# 27        75   251.0   4000.0     0.0    1800   2557
# 28        75    85.0   5000.0     0.0     600   1600
# 29        35     NaN      NaN     NaN    1500   1850
# 30        45   150.0   5000.0  3300.0    1100   1312
# 31        45   122.0   2500.0     0.0     400    400
# 32        75   198.0   1000.0     0.0     450    650

# %%
### REMPLAZAR VALORES CREAMOS EL VALOR MEDIANA QUE ES CON EL QUE SE VA A REEMPLAZAR 

income_median= df["income"].median()
assets_median= df["assets"].median()
debt_median= df["debt"].median()
df.head(39)
# Out:
#      status  seniority     home  time  age  marital records        job  \
# 0        ok          9     rent    60   30  married      no  freelance
# 1        ok         17     rent    60   58    widow      no      fixed
# 2   default         10    owner    36   46  married     yes  freelance
# 3        ok          0     rent    60   24   single      no      fixed
# 4        ok          0     rent    36   26   single      no      fixed
# 5        ok          1    owner    60   36  married      no      fixed
# 6        ok         29    owner    60   44  married      no      fixed
# 7        ok          9  parents    12   27   single      no      fixed
# 8        ok          0    owner    60   32  married      no  freelance
# 9   default          0  parents    48   41  married      no    partime
# 10       ok          6    owner    48   34  married      no  freelance
# 11       ok          7    owner    36   29  married      no      fixed
# 12       ok          8    owner    60   30  married      no      fixed
# 13       ok         19  private    36   37  married      no      fixed
# 14  default          0    other    18   21   single     yes    partime
# 15       ok          0    owner    24   68  married      no      fixed
# 16       ok         15  private    24   52   single      no  freelance
# 17       ok         33     rent    24   68  married      no  freelance
# 18  default          0   ignore    48   36  married      no    partime
# 19       ok          1  parents    60   31   single      no      fixed
# 20  default          2     rent    60   25   single      no      fixed
# 21       ok          5    owner    60   22   single      no      fixed
# 22  default          1    owner    60   45  married      no    partime
# 23       ok         27     rent    60   41  married      no      fixed
# 24       ok         26    owner    60   51  married      no      fixed
# 25       ok         12    owner    36   54  married      no      fixed
# 26       ok         19    owner    60   43   single      no      fixed
# 27       ok         15    owner    36   43  married      no      fixed
# 28  default          3    owner    24   23  married      no      fixed
# 29  default          0      unk    48   37   single      no        unk
# 30       ok          4    owner    48   29  married      no      fixed
# 31  default          0    owner    36   23   single      no    partime
# 32       ok         14  private    24   51  married      no    partime
# 33       ok         10    owner    36   39  married      no  freelance
# 34       ok         12  parents    36   35   single      no      fixed
# 35       ok         32    owner    24   62  married      no  freelance
# 36       ok         10    owner    24   56  married      no  freelance
# 37       ok          7    owner    48   32  married      no      fixed
# 38  default          1     rent    54   36  married      no      fixed
#
#     expenses  income   assets    debt  amount  price
# 0         73   129.0      0.0     0.0     800    846
# 1         48   131.0      0.0     0.0    1000   1658
# 2         90   200.0   3000.0     0.0    2000   2985
# 3         63   182.0   2500.0     0.0     900   1325
# 4         46   107.0      0.0     0.0     310    910
# 5         75   214.0   3500.0     0.0     650   1645
# 6         75   125.0  10000.0     0.0    1600   1800
# 7         35    80.0      0.0     0.0     200   1093
# 8         90   107.0  15000.0     0.0    1200   1957
# 9         90    80.0      0.0     0.0    1200   1468
# 10        60   125.0   4000.0     0.0    1150   1577
# 11        60   121.0   3000.0     0.0     650    915
# 12        75   199.0   5000.0  2500.0    1500   1650
# 13        75   170.0   3500.0   260.0     600    940
# 14        35    50.0      0.0     0.0     400    500
# 15        75   131.0   4162.0     0.0     900   1186
# 16        35   330.0  16500.0     0.0    1500   2201
# 17        65   200.0   5000.0  2000.0     600   1350
# 18        45   130.0    750.0     0.0    1100   1511
# 19        35   137.0      0.0     0.0    1250   1253
# 20        46   107.0      0.0     0.0    1500   2189
# 21        45   324.0  10000.0     0.0    1100   1159
# 22       105   112.0   2000.0   500.0     600   1332
# 23        74   140.0      0.0     0.0     950   1497
# 24        45   143.0   3500.0     0.0    1350   1357
# 25        60   130.0   4000.0     0.0     700   2100
# 26        75   180.0   4000.0     0.0    1000   1070
# 27        75   251.0   4000.0     0.0    1800   2557
# 28        75    85.0   5000.0     0.0     600   1600
# 29        35     NaN      NaN     NaN    1500   1850
# 30        45   150.0   5000.0  3300.0    1100   1312
# 31        45   122.0   2500.0     0.0     400    400
# 32        75   198.0   1000.0     0.0     450    650
# 33        75   150.0   3000.0     0.0    1000   1394
# 34        35   170.0      0.0     0.0    1100   1542
# 35        45   119.0   8500.0     0.0     700   1200
# 36        45   208.0  13500.0     0.0     500   1560
# 37        75   115.0   3000.0     0.0     800   1200
# 38        70    99.0      0.0     0.0     950    950

# %%
df["income"].fillna(income_median, inplace= True)
df["assets"].fillna(assets_median, inplace= True)
df["debt"].fillna(debt_median, inplace= True)

income_median= df["income"].median()
assets_median= df["assets"].median()
debt_median= df["debt"].median()


df.head(30)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15612\245238908.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["income"].fillna(income_median, inplace= True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15612\245238908.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["assets"].fillna(assets_median, inplace= True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15612\245238908.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["debt"].fillna(debt_median, inplace= True)
#      status  seniority     home  time  age  marital records        job  \
# 0        ok          9     rent    60   30  married      no  freelance
# 1        ok         17     rent    60   58    widow      no      fixed
# 2   default         10    owner    36   46  married     yes  freelance
# 3        ok          0     rent    60   24   single      no      fixed
# 4        ok          0     rent    36   26   single      no      fixed
# 5        ok          1    owner    60   36  married      no      fixed
# 6        ok         29    owner    60   44  married      no      fixed
# 7        ok          9  parents    12   27   single      no      fixed
# 8        ok          0    owner    60   32  married      no  freelance
# 9   default          0  parents    48   41  married      no    partime
# 10       ok          6    owner    48   34  married      no  freelance
# 11       ok          7    owner    36   29  married      no      fixed
# 12       ok          8    owner    60   30  married      no      fixed
# 13       ok         19  private    36   37  married      no      fixed
# 14  default          0    other    18   21   single     yes    partime
# 15       ok          0    owner    24   68  married      no      fixed
# 16       ok         15  private    24   52   single      no  freelance
# 17       ok         33     rent    24   68  married      no  freelance
# 18  default          0   ignore    48   36  married      no    partime
# 19       ok          1  parents    60   31   single      no      fixed
# 20  default          2     rent    60   25   single      no      fixed
# 21       ok          5    owner    60   22   single      no      fixed
# 22  default          1    owner    60   45  married      no    partime
# 23       ok         27     rent    60   41  married      no      fixed
# 24       ok         26    owner    60   51  married      no      fixed
# 25       ok         12    owner    36   54  married      no      fixed
# 26       ok         19    owner    60   43   single      no      fixed
# 27       ok         15    owner    36   43  married      no      fixed
# 28  default          3    owner    24   23  married      no      fixed
# 29  default          0      unk    48   37   single      no        unk
#
#     expenses  income   assets    debt  amount  price
# 0         73   129.0      0.0     0.0     800    846
# 1         48   131.0      0.0     0.0    1000   1658
# 2         90   200.0   3000.0     0.0    2000   2985
# 3         63   182.0   2500.0     0.0     900   1325
# 4         46   107.0      0.0     0.0     310    910
# 5         75   214.0   3500.0     0.0     650   1645
# 6         75   125.0  10000.0     0.0    1600   1800
# 7         35    80.0      0.0     0.0     200   1093
# 8         90   107.0  15000.0     0.0    1200   1957
# 9         90    80.0      0.0     0.0    1200   1468
# 10        60   125.0   4000.0     0.0    1150   1577
# 11        60   121.0   3000.0     0.0     650    915
# 12        75   199.0   5000.0  2500.0    1500   1650
# 13        75   170.0   3500.0   260.0     600    940
# 14        35    50.0      0.0     0.0     400    500
# 15        75   131.0   4162.0     0.0     900   1186
# 16        35   330.0  16500.0     0.0    1500   2201
# 17        65   200.0   5000.0  2000.0     600   1350
# 18        45   130.0    750.0     0.0    1100   1511
# 19        35   137.0      0.0     0.0    1250   1253
# 20        46   107.0      0.0     0.0    1500   2189
# 21        45   324.0  10000.0     0.0    1100   1159
# 22       105   112.0   2000.0   500.0     600   1332
# 23        74   140.0      0.0     0.0     950   1497
# 24        45   143.0   3500.0     0.0    1350   1357
# 25        60   130.0   4000.0     0.0     700   2100
# 26        75   180.0   4000.0     0.0    1000   1070
# 27        75   251.0   4000.0     0.0    1800   2557
# 28        75    85.0   5000.0     0.0     600   1600
# 29        35   120.0   3000.0     0.0    1500   1850

# %%
df.isnull().sum()
# Out:
# status       0
# seniority    0
# home         0
# time         0
# age          0
# marital      0
# records      0
# job          0
# expenses     0
# income       0
# assets       0
# debt         0
# amount       0
# price        0
# dtype: int64

# %% [markdown]
# ### Preguntas y respuestas

# %%
### ¿Cuantos clientes se encuentran al corriente y cuantos en atraso? 

sns.countplot(x= "status", data=df,
             palette= "Oranges")


plt.title("Comportamiento de Pagos")

plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15612\2955213828.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= "status", data=df,
# C:\Users\Admin\OneDrive - GRUPO OLINX S.A. DE C.V\Documentos\Ciencia de Datos\Caso Practico Bedu Python\.venv\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Admin\OneDrive - GRUPO OLINX S.A. DE C.V\Documentos\Ciencia de Datos\Caso Practico Bedu Python\.venv\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
#¿Cuantas categorias en hogar existen?

sns.countplot(x="home", data=df, order=df["home"].value_counts().index,
              palette= "Blues")


plt.title("Tipos de Hogar")

plt.xlabel("Tipos de Hogar")
plt.ylabel("Numero de clientes por tipo de hogar")

plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15612\3779210314.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="home", data=df, order=df["home"].value_counts().index,
# C:\Users\Admin\OneDrive - GRUPO OLINX S.A. DE C.V\Documentos\Ciencia de Datos\Caso Practico Bedu Python\.venv\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Admin\OneDrive - GRUPO OLINX S.A. DE C.V\Documentos\Ciencia de Datos\Caso Practico Bedu Python\.venv\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Admin\OneDrive - GRUPO OLINX S.A. DE C.V\Documentos\Ciencia de Datos\Caso Practico Bedu Python\.venv\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Admin\OneDrive - GRUPO OLINX S.A. DE C.V\Documentos\Ciencia de Datos\Caso Practico Bedu Python\.venv\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Admin\OneDrive - GRUPO OLINX S.A. DE C.V\Documentos\Ciencia de Datos\Caso Practico Bedu Python\.venv\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Admin\OneDrive - GRUPO OLINX S.A. DE C.V\Documentos\Ciencia de Datos\Caso Practico Bedu Python\.venv\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Admin\OneDrive - GRUPO OLINX S.A. DE C.V\Documentos\Ciencia de Datos\Caso Practico Bedu Python\.venv\lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
